# %% [markdown]
# ## First Week Stepik DS

# %%
import pandas as pd
import numpy as np

# %%
student_performance = pd.read_csv("./StudentsPerformance.csv")

# %% [markdown]
# Show some stat and data type in your dataframe

# %%
student_performance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
student_performance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# `groupby` function

# %%
student_performance.groupby('gender').aggregate({'writing score': 'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
student_performance.size
# Out:
# 8000

# %%
student_performance.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# Selection with `iloc` for index and `loc` for index order

# %%
student_performance.iloc[[0,3,-1], 0:-3]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course
# 0                      none
# 3                      none
# 999                    none

# %%
student_performance_with_names = student_performance.iloc[[0, 3, 4, 7, 8]]

# %% [markdown]
# How to use index names for `df`

# %%
student_performance_with_names.index = ['Cersei', 'Tywin', 'Gregor', 'Joffrey', 'Ilyn Payne']

# %%
student_performance_with_names
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# Cersei      female        group B           bachelor's degree      standard
# Tywin         male        group A          associate's degree  free/reduced
# Gregor        male        group C                some college      standard
# Joffrey       male        group B                some college  free/reduced
# Ilyn Payne    male        group D                 high school  free/reduced
#
#            test preparation course  math score  reading score  writing score
# Cersei                        none          72             72             74
# Tywin                         none          47             57             44
# Gregor                        none          76             78             75
# Joffrey                       none          40             43             39
# Ilyn Payne               completed          64             64             67

# %%
student_performance_with_names.loc[['Cersei', 'Joffrey'], ['gender', 'writing score']]
# Out:
#          gender  writing score
# Cersei   female             74
# Joffrey    male             39

# %%
type(student_performance_with_names.iloc[:, :])
# Out:
# pandas.core.frame.DataFrame

# %%
my_ser_1 = pd.Series([1,2,4], index = ['first', 'second', 'third'])

# %%
my_ser_2 = pd.Series([4,5,6], index=['fourt','fiveth','sixth'])

# %%
merged_df = pd.DataFrame({'col_name_1':my_ser_1, 'col_name_2':my_ser_2})

# %% [markdown]
# Some usefull about Series and DataFrame

# %%
type(student_performance_with_names[['gender']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(student_performance_with_names['gender'])
# Out:
# pandas.core.series.Series

# %%
(student_performance_with_names['gender']).shape
# Out:
# (5,)

# %% [markdown]
# ## Week 1.5

# %%
student_performance.loc[student_performance.gender == 'male', ['gender', 'writing score']]
# Out:
#     gender  writing score
# 3     male             44
# 4     male             75
# 7     male             39
# 8     male             67
# 10    male             52
# ..     ...            ...
# 985   male             54
# 987   male             76
# 990   male             75
# 994   male             62
# 996   male             55
#
# [482 rows x 2 columns]

# %%
student_performance['writing score']
# Out:
# 0      74
# 1      88
# 2      93
# 3      44
# 4      75
#        ..
# 995    95
# 996    55
# 997    65
# 998    77
# 999    86
# Name: writing score, Length: 1000, dtype: int64

# %%
mean_wr = student_performance['writing score'].mean()

# %%
student_performance.loc[student_performance['writing score'] > mean_wr]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
query = (student_performance['writing score'] > mean_wr) & (student_performance.gender == 'female')

# %%
student_performance.loc[query]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student_performance.columns = [x.replace(' ','_') for x in student_performance.columns]

# %%
writing_score_level = 60

# %%
student_performance.query("gender == 'male' | writing_score > @writing_score_level").size
# Out:
# 7200

# %%
score_names = [i for i in list(student_performance) if 'score' in i]

# %%
student_performance[score_names].head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
student_performance.filter(like = 'score')
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
student_performance_with_names.filter(like = 'f', axis = 0)
# Out:
#         gender race/ethnicity parental level of education         lunch  \
# Joffrey   male        group B                some college  free/reduced
#
#         test preparation course  math score  reading score  writing score
# Joffrey                    none          40             43             39

# %% [markdown]
# Method `groupby`

# %%
student_performance.groupby('gender').mean()
# Out:
#         math_score  reading_score  writing_score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
student_performance.groupby(['gender', 'race/ethnicity'], as_index = False).aggregate\
            ({'math_score': 'mean', 'reading_score':'mean'})\
           # .rename(columns={'math_score':'mean_math_score','reading_score':'mean_reading'})
# Out:
#    gender race/ethnicity  math_score  reading_score
# 0  female        group A   58.527778      69.000000
# 1  female        group B   61.403846      71.076923
# 2  female        group C   62.033333      71.944444
# 3  female        group D   65.248062      74.046512
# 4  female        group E   70.811594      75.840580
# 5    male        group A   63.735849      61.735849
# 6    male        group B   65.930233      62.848837
# 7    male        group C   67.611511      65.424460
# 8    male        group D   69.413534      66.135338
# 9    male        group E   76.746479      70.295775

# %%
math_scores = student_performance.groupby(['gender', 'race/ethnicity'], as_index = True).aggregate\
            ({'math_score': 'mean', 'reading_score':'mean'})\
            .rename(columns={'math_score':'mean_math_score','reading_score':'mean_reading'})

# %%
math_scores.loc[[('female', 'group A'), ('female', 'group B')]]
# Out:
#                        mean_math_score  mean_reading
# gender race/ethnicity
# female group A               58.527778     69.000000
#        group B               61.403846     71.076923

# %%
student_performance.sort_values(['gender', 'math_score'], ascending=False)\
    .groupby('gender').head(5)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %%
student_performance['total_score'] =

# %%
student_performance['total_score'] = student_performance.math_score + student_performance.writing_score + student_performance.reading_score

# %%
student_performance =student_performance.assign(total_score_log = np.log(student_performance.total_score))

# %%
student_performance.drop(['total_score'], axis = 1)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
dota_hero = pd.read_csv('./dota_hero_stats.csv')

# %%
dota_hero.groupby('legs').size()
# Out:
# legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1
# dtype: int64

# %%
pupa_lupa = pd.read_csv('https://stepik.org/media/attachments/course/4852/accountancy.csv')

# %%
pupa_lupa.groupby(['Type', 'Executor']).aggregate({'Salary':'max'})
# Out:
#                Salary
# Type Executor
# A    Loopa         58
#      Pupa         234
# B    Loopa        249
#      Pupa          77
# C    Loopa        249
#      Pupa          94
# D    Loopa        181
#      Pupa         194
# E    Loopa        220
#      Pupa         197
# F    Loopa        244
#      Pupa         195

# %%
dota_hero.groupby(['attack_type','primary_attr']).aggregate({'attack_type':'count', 'primary_attr':'count'})
# Out:
#                           attack_type  primary_attr
# attack_type primary_attr
# Melee       agi                    19            19
#             int                     2             2
#             str                    35            35
# Ranged      agi                    18            18
#             int                    40            40
#             str                     3             3

# %%
metabolom = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')

# %%
metabolom.head(5)
# Out:
#                species       genus  group   sucrose    alanin   citrate  \
# 0    Fucus_vesiculosus       Fucus  brown  3.001472  3.711498  5.004262
# 1  Saccharina_japonica  Saccharina  brown  6.731070  1.255251  5.621499
# 2       Fucus_serratus       Fucus  brown  3.276870  0.346431  1.216767
# 3      Fucus_distichus       Fucus  brown  6.786996  6.641303  6.423606
# 4    Cladophora_fracta  Cladophora  green  3.861470  1.648450  6.940588
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886

# %%
metabolom.groupby('group', as_index=False).aggregate(['min', 'max'])
# Out:
#                    species                              genus              \
#                        min                   max          min         max
# group
# brown  Ascophyllum_nodosum  Saccharina_latissima  Ascophyllum  Saccharina
# green  Cladophora_compacta   Cladophora_gracilis   Cladophora  Cladophora
# red       Palmaria_palmata      Palmaria_palmata     Palmaria    Palmaria
#
#         sucrose              alanin             citrate             glucose  \
#             min       max       min       max       min       max       min
# group
# brown  1.636122  6.825467  0.346431  6.641303  1.071920  6.423606  2.272724
# green  2.452623  5.712284  1.648450  6.881024  3.082826  6.940588  2.316955
# red    0.704580  0.704580  3.176440  3.176440  5.573905  5.573905  3.242090
#
#                 oleic_acid
#             max        min       max
# group
# brown  6.013219   0.304573  6.405165
# green  3.343707   1.432514  2.829016
# red    3.242090   2.245538  2.245538

# %%
#metabolom.query('genus == "Fucus"').aggregate(['mean', 'max', 'min'])
